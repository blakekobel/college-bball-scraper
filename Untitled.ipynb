# %%
import pandas as pd

# %%
df = pd.read_csv('11-25.csv')

# %%
df
# Out:
#              espn_name            sr_name            kp_name  KenPomRank  \
# 0    Abilene Christian  Abilene Christian  Abilene Christian         128
# 1            Air Force          Air Force          Air Force         256
# 2                Akron              Akron              Akron         143
# 3              Alabama            Alabama            Alabama          49
# 4          Alabama A&M        Alabama A&M        Alabama A&M         340
# ..                 ...                ...                ...         ...
# 342            Wofford            Wofford            Wofford         140
# 343       Wright State       Wright State         Wright St.         113
# 344            Wyoming            Wyoming            Wyoming         197
# 345             Xavier             Xavier             Xavier          63
# 346   Youngstown State   Youngstown State     Youngstown St.         186
#
#      KenPomVal  BPIrank  BPIval    SRS   o_eff  d_eff   ppg  papg  Pace  \
# ...

# %%
df['random_column'] = df['KenPomVal'] * df['BPIval']

# %%
df
# Out:
#              espn_name            sr_name            kp_name  KenPomRank  \
# 0    Abilene Christian  Abilene Christian  Abilene Christian         128
# 1            Air Force          Air Force          Air Force         256
# 2                Akron              Akron              Akron         143
# 3              Alabama            Alabama            Alabama          49
# 4          Alabama A&M        Alabama A&M        Alabama A&M         340
# ..                 ...                ...                ...         ...
# 342            Wofford            Wofford            Wofford         140
# 343       Wright State       Wright State         Wright St.         113
# 344            Wyoming            Wyoming            Wyoming         197
# 345             Xavier             Xavier             Xavier          63
# 346   Youngstown State   Youngstown State     Youngstown St.         186
#
#      KenPomVal  BPIrank  BPIval    SRS   o_eff  d_eff  ...  papg  Pace  \
# ...
