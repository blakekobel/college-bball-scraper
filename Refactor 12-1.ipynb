# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv("12-1.csv")
tf = pd.read_csv("teams_table.csv")

# %%
df
# Out:
#       teamID                        metric  value                 date
# 0        104                        KenPom  29.33  2020-12-01 19:14:48
# 1         21                        KenPom  28.08  2020-12-01 19:14:48
# 2        335                        KenPom  24.90  2020-12-01 19:14:48
# 3         75                        KenPom  24.60  2020-12-01 19:14:48
# 4        294                        KenPom  24.01  2020-12-01 19:14:48
# ...      ...                           ...    ...                  ...
# 4971     356             Opp_True_Shooting    NaN  2020-12-01 19:14:48
# 4972     356             Opp_Turnover_Perc    NaN  2020-12-01 19:14:48
# 4973     357  Opp_Three_Point_Attempt_Rate    NaN  2020-12-01 19:14:48
# 4974     357             Opp_True_Shooting    NaN  2020-12-01 19:14:48
# 4975     357             Opp_Turnover_Perc    NaN  2020-12-01 19:14:48
#
# [4976 rows x 4 columns]

# %%
tf
# Out:
#       id        kenpom_name            sr_name           bpi_name  \
# 0      1  Abilene Christian  Abilene Christian  Abilene Christian
# 1      2          Air Force          Air Force          Air Force
# 2      3              Akron              Akron              Akron
# 3      4            Alabama            Alabama            Alabama
# 4      5        Alabama A&M        Alabama A&M        Alabama A&M
# ..   ...                ...                ...                ...
# 352  353         Wright St.       Wright State       Wright State
# 353  354            Wyoming            Wyoming            Wyoming
# 354  355             Xavier             Xavier             Xavier
# 355  356               Yale               Yale               Yale
# 356  357     Youngstown St.   Youngstown State   Youngstown State
#
#      extra_name1  extra_name2  extra_name3
# 0            NaN          NaN          NaN
# 1            NaN          NaN          NaN
# ...

# %%
if "Akron" in tf['kenpom_name'].unique():
    print(tf[tf['bpi_name'] == "Akron"]['id'].values[0])

# for x in df['team_name']:
#     val = x in tf['kenpom_name'].unique() or x in tf['sr_name'].unique() or x in tf['bpi_name'].unique()
#     print(x,val)
# Out:
# 2    3
# Name: id, dtype: int64

# %%
# a = tf.loc[(tf['kenpom_name'] == "Kansas"),['id']].index.values
a = tf[tf['kenpom_name']=='Kansas']['id'].values[0]
print(a)
# Out:
# 134

# %%
df['id'] = np.where(df['team_name'] in tf['kenpom_name'].unique(),"KenPom val exists","NOpe")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-079432e3e3bd> in <module>
# ----> 1 df['id'] = np.where(df['team_name'] in tf['kenpom_name'].unique(),"KenPom val exists","NOpe")
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other)
# ...

# %%
df = df.merge(tf, how='left', left_on="team_name", right_on="kenpom_name")
df = df[['team_name','metric','value','date','id']]
df = df.merge(tf, how='left', left_on="team_name", right_on="sr_name",suffixes=('', '_rightsr'))
df = df.merge(tf, how='left', left_on="team_name", right_on="bpi_name",suffixes=('', '_rightbpi'))

# %%
df
# Out:
#              team_name                        metric  value  \
# 0              Gonzaga                        KenPom  29.33
# 1               Baylor                        KenPom  28.29
# 2                 Duke                        KenPom  24.60
# 3            Villanova                        KenPom  24.33
# 4               Kansas                        KenPom  23.75
# ...                ...                           ...    ...
# 4971              Yale             Opp_True_Shooting    NaN
# 4972              Yale             Opp_Turnover_Perc    NaN
# 4973  Youngstown State  Opp_Three_Point_Attempt_Rate    NaN
# 4974  Youngstown State             Opp_True_Shooting    NaN
# 4975  Youngstown State             Opp_Turnover_Perc    NaN
#
#                      date     id  id_rightsr     kenpom_name  \
# 0     2020-12-01 14:45:17  104.0       104.0         Gonzaga
# 1     2020-12-01 14:45:17   21.0        21.0          Baylor
# ...

# %%
result.to_csv('refactored_statlines.csv',index=False)
